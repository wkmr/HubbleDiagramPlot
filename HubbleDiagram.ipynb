# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
#Change the values in the lists below to the radial velocities and distances that you've estimated, leaving the zeros.
radvel = [0.0,200.0,500.0,750.0,1000.0,1500.0]
dist = [0.0,9.2,23.0,34.5,46.0,69.0]

# %%
plt.scatter(dist,radvel)

#change the numbers in the plot below to draw your best-fit line through your data points. Don't change the zeros.
plt.plot([0.0,80.0],[0.0,1700.0])

plt.xlim(0.0,80.0)
plt.ylim(0.0,1750.0)

plt.xlabel('Distance (Mly)')
plt.ylabel('Radial velocity (km/s)')

plt.savefig('HubbleDiagram.png')

plt.show()
