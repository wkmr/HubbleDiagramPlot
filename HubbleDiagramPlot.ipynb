# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
#Enter your 5 radial velocities below (in km/s).
x1 = 
x2 = 
x3 = 
x4 = 
x5 = 

#Enter your 5 distances below (in Mly)
y1 =
y2 = 
y3 = 
y4 = 
y5 = 

radvel = [0.0,x1,x2,x3,x4,x5]
dist = [0.0,y1,y2,y3,y4,y5]

plt.scatter(dist, radvel)

plt.xlabel('Distance (Mly)')
plt.ylabel('Radial velocity (km/s)')

plt.show()

# %%
plt.scatter(dist,radvel)

#Enter x and y below below to values that will draw a best-fit line through your data points.
x = 
y = 
plt.plot([0.0,x],[0.0,y])

plt.xlabel('Distance (Mly)')
plt.ylabel('Radial velocity (km/s)')

plt.show()

# %%
plt.scatter(dist,radvel)

#Enter x and y below below to values that will draw a best-fit line through your data points.
plt.plot([0.0,x],[0.0,y])

#Enter x and y values that will set the axis limits for your plot.
xmax =
ymax = 


plt.xlim(0.0,xmax)
plt.ylim(0.0,ymax)

plt.xlabel('Distance (Mly)')
plt.ylabel('Radial velocity (km/s)')

plt.savefig('HubbleDiagram.png')

plt.show()
